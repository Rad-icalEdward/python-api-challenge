# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
import datetime

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = list(zip(lats, lngs))

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 617

# %%
lat_lngs
# Out:
# [(-62.12294705893511, -74.41054672426088),
#  (-55.09719999914768, -112.52044462954196),
#  (-62.611397804622925, 45.843536453595874),
#  (44.139431301869365, 19.73144697409495),
#  (-2.450474549629135, 3.409799252207449),
#  (20.575622631407512, -84.47762697623719),
#  (88.69870424447203, 145.82559115054875),
#  (63.170946064555835, -129.34990647973507),
#  (51.845048013956045, -91.12895081961835),
#  (76.54060078912062, -87.15810835225409),
#  (40.1509669680475, 136.5622046842539),
#  (-16.494285786050114, 55.163536930782556),
#  (29.038260021099816, 100.03380838016437),
#  (-31.882556058826815, 30.113873605056398),
#  (-34.305190616397525, 58.527469935888064),
#  (-43.456168336922296, 131.2907336848573),
#  (-41.46181652078157, -113.96506197187924),
#  (60.487935996738344, 138.7549935760806),
#  (4.724765973288413, -61.87492114835774),
#  (-81.74657832214156, -145.44703056820546),
#  (86.16399624993258, -122.55756326009914),
#  (35.400556134326195, 30.152161300976303),
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = "https://api.openweathermap.org/data/2.5/weather?q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0     
    
    api_key = f"&appid={weather_api_key}"
    units = f"&units=metric"
    
    # Create endpoint URL with each city
    city_url = base_url + city + api_key + units
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
 # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | valjevo
# Processing Record 5 of Set 1 | port-gentil
# Processing Record 6 of Set 1 | guane
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | norman wells
# Processing Record 9 of Set 1 | sioux lookout
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | wajima
# Processing Record 12 of Set 1 | cap malheureux
# Processing Record 13 of Set 1 | xichang
# Processing Record 14 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | port lincoln
# Processing Record 17 of Set 1 | solnechnyy
# Processing Record 18 of Set 1 | boa vista
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | tuktoyaktuk
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      ushuaia -54.8000  -68.3000      6.79        81         100        1.54
# 1      rikitea -23.1203 -134.9692     27.06        68         100        8.18
# 2  east london -33.0153   27.9116     22.52        83           0        3.09
# 3      valjevo  44.2751   19.8982      3.77        64          92        0.85
# 4  port-gentil  -0.7193    8.7815     28.35        79          47        5.61
#
#   Country        Date
# 0      AR  1678039894
# 1      PF  1678039901
# 2      ZA  1678039920
# 3      RS  1678039920
# 4      GA  1678039662

# %%
# Display sample data
city_data_df["Date"] = pd.to_datetime(city_data_df["Date"], unit='s')

city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      ushuaia -54.8000  -68.3000      6.79        81         100        1.54
# 1      rikitea -23.1203 -134.9692     27.06        68         100        8.18
# 2  east london -33.0153   27.9116     22.52        83           0        3.09
# 3      valjevo  44.2751   19.8982      3.77        64          92        0.85
# 4  port-gentil  -0.7193    8.7815     28.35        79          47        5.61
#
#   Country                Date
# 0      AR 2023-03-05 18:11:34
# 1      PF 2023-03-05 18:11:41
# 2      ZA 2023-03-05 18:12:00
# 3      RS 2023-03-05 18:12:00
# 4      GA 2023-03-05 18:07:42

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            ushuaia -54.8000  -68.3000      6.79        81         100
# 1            rikitea -23.1203 -134.9692     27.06        68         100
# 2        east london -33.0153   27.9116     22.52        83           0
# 3            valjevo  44.2751   19.8982      3.77        64          92
# 4        port-gentil  -0.7193    8.7815     28.35        79          47
#
#          Wind Speed Country                 Date
# City_ID
# 0              1.54      AR  2023-03-05 18:11:34
# 1              8.18      PF  2023-03-05 18:11:41
# 2              3.09      ZA  2023-03-05 18:12:00
# 3              0.85      RS  2023-03-05 18:12:00
# 4              5.61      GA  2023-03-05 18:07:42

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
cities_latitude = city_data_df["Lat"]
cities_max_temp = city_data_df["Max Temp"]

plt.scatter(cities_latitude, cities_max_temp)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs. Max Temperature")

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
cities_humidity = city_data_df["Humidity"]

plt.scatter(cities_latitude, cities_humidity)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("City Max Latitude vs. Humidity")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
cities_cloudiness = city_data_df["Cloudiness"]

plt.scatter(cities_latitude, cities_cloudiness)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Max Latitude vs. Cloudiness")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
cities_wind_speed = city_data_df["Wind Speed"]

plt.scatter(cities_latitude, cities_wind_speed)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Max Latitude vs. Wind Speed")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# Latitude vs. max temp
correlation_1 = st.pearsonr(cities_latitude, cities_max_temp)
print(f"The correlation between city latitude and city max temperature is {round(correlation_1[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(cities_latitude, cities_max_temp)
regress_values_1 = cities_latitude * slope + intercept
line_eq_1 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Latitude vs. humidity
correlation_2 = st.pearsonr(cities_latitude, cities_humidity)
print(f"The correlation between city latitude and city humidity is {round(correlation_2[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(cities_latitude, cities_humidity)
regress_values_2 = cities_latitude * slope + intercept
line_eq_2 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Latitude vs. cloudiness
correlation_3 = st.pearsonr(cities_latitude, cities_cloudiness)
print(f"The correlation between city latitude and city cloudiness is {round(correlation_3[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(cities_latitude, cities_cloudiness)
regress_values_3 = cities_latitude * slope + intercept
line_eq_3 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Latitude vs. wind speed
correlation_4 = st.pearsonr(cities_latitude, cities_wind_speed)
print(f"The correlation between city latitude and city wind speed is {round(correlation_4[0],2)}")

(slope, intercept, rvalue, pvalue, stderr) = linregress(cities_latitude, cities_wind_speed)
regress_values_4 = cities_latitude * slope + intercept
line_eq_4 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# Out:
# The correlation between city latitude and city max temperature is -0.72
# The correlation between city latitude and city humidity is 0.11
# The correlation between city latitude and city cloudiness is 0.16
# The correlation between city latitude and city wind speed is -0.12

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3              valjevo  44.2751   19.8982      3.77        64          92
# 5                guane  22.2025  -84.0875     30.44        45           4
# 6           chokurdakh  70.6333  147.9167    -45.42       100          51
# 7         norman wells  65.2820 -126.8329    -31.98        68          20
# 8        sioux lookout  50.1001  -91.9170      1.04        55          20
#
#          Wind Speed Country                 Date
# City_ID
# 3              0.85      RS  2023-03-05 18:12:00
# 5              5.04      CU  2023-03-05 18:12:01
# 6              1.28      RU  2023-03-05 18:12:01
# 7              0.00      CA  2023-03-05 18:12:01
# 8              2.06      CA  2023-03-05 18:12:01

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               ushuaia -54.8000  -68.3000      6.79        81         100
# 1               rikitea -23.1203 -134.9692     27.06        68         100
# 2           east london -33.0153   27.9116     22.52        83           0
# 4           port-gentil  -0.7193    8.7815     28.35        79          47
# 11       cap malheureux -19.9842   57.6142     25.26        87         100
#
#          Wind Speed Country                 Date
# City_ID
# 0              1.54      AR  2023-03-05 18:11:34
# 1              8.18      PF  2023-03-05 18:11:41
# 2              3.09      ZA  2023-03-05 18:12:00
# 4              5.61      GA  2023-03-05 18:07:42
# 11             8.68      MU  2023-03-05 18:09:54

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
northern_city_latitude = northern_hemi_df["Lat"]
northern_city_temp = northern_hemi_df["Max Temp"]

plt.scatter(northern_city_latitude, northern_city_temp)

plt.plot(northern_city_latitude,regress_values_1,"r-")
plt.annotate(line_eq_1,(5.8,0.8),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs. Max Temperature")

# Show the chart.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2152\3266502225.py in <module>
#       5 plt.scatter(northern_city_latitude, northern_city_temp)
#       6
# ----> 7 plt.plot(northern_city_latitude,regress_values_1,"r-")
#       8 plt.annotate(line_eq_1,(5.8,0.8),fontsize=15,color="red")
#       9 plt.xlabel("Latitude")
#
# D:\Data-Analytics\Anaconda\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# D:\Data-Analytics\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
